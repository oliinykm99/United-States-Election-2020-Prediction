# %% [markdown]
# <h1><center> TITLE </center></h1>
# <h4><center>Maksym Oliinyk, 1004506377 <br> Big Data Tools for Economists (ECO225H1 S)</center></h4>
#
# ---
# <h2><bold> Outline: </bold></h2>
#
# 1. Introduction
# 2. Data Analysis
# 3. Summary
# 4. Future Steps

# %% [markdown]
# <h2><center> Introduction </center></h2>
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_president =  pd.read_csv(r"/Users/maximolii/Desktop/UofT/Years/Fourth Year/2/ECO225/Project/ECO225Project/Data/president_county_candidate.csv")

df_president.head()
df_president.tail()
# Out:
#          state           county     candidate party  total_votes    won
# 32172  Arizona  Maricopa County     Write-ins   WRI         1331  False
# 32173  Arizona    Mohave County  Donald Trump   REP        78535   True
# 32174  Arizona    Mohave County     Joe Biden   DEM        24831  False
# 32175  Arizona    Mohave County  Jo Jorgensen   LIB         1302  False
# 32176  Arizona    Mohave County     Write-ins   WRI           37  False

# %% [markdown]
# <h2><center> Data Analysis </center></h2>
#
# ---

# %%
df_candidate = df_president.groupby("state")

df_candidate.get_group("Arizona")
# Out:
#          state             county     candidate party  total_votes    won
# 32117  Arizona      Navajo County  Donald Trump   REP        27657   True
# 32118  Arizona      Navajo County     Joe Biden   DEM        23383  False
# 32119  Arizona      Navajo County  Jo Jorgensen   LIB          727  False
# 32120  Arizona      Navajo County     Write-ins   WRI           16  False
# 32121  Arizona        Pima County     Joe Biden   DEM       304981   True
# 32122  Arizona        Pima County  Donald Trump   REP       207758  False
# 32123  Arizona        Pima County  Jo Jorgensen   LIB         7658  False
# 32124  Arizona        Pima County     Write-ins   WRI          338  False
# 32125  Arizona       Pinal County  Donald Trump   REP       107077   True
# 32126  Arizona       Pinal County     Joe Biden   DEM        75106  False
# 32127  Arizona       Pinal County  Jo Jorgensen   LIB         2791  False
# 32128  Arizona       Pinal County     Write-ins   WRI           63  False
# 32129  Arizona  Santa Cruz County     Joe Biden   DEM        13138   True
# 32130  Arizona  Santa Cruz County  Donald Trump   REP         6194  False
# 32131  Arizona  Santa Cruz County  Jo Jorgensen   LIB          224  False
# 32132  Arizona  Santa Cruz County     Write-ins   WRI            5  False
# 32133  Arizona     Yavapai County  Donald Trump   REP        91527   True
# 32134  Arizona     Yavapai County     Joe Biden   DEM        49602  False
# 32135  Arizona     Yavapai County  Jo Jorgensen   LIB         2092  False
# 32136  Arizona     Yavapai County     Write-ins   WRI           59  False
# 32137  Arizona        Yuma County  Donald Trump   REP        36534   True
# 32138  Arizona        Yuma County     Joe Biden   DEM        32210  False
# 32139  Arizona        Yuma County  Jo Jorgensen   LIB         1137  False
# 32140  Arizona        Yuma County     Write-ins   WRI           45  False
# 32141  Arizona      Apache County     Joe Biden   DEM        23293   True
# 32142  Arizona      Apache County  Donald Trump   REP        11442  False
# 32143  Arizona      Apache County  Jo Jorgensen   LIB          437  False
# 32144  Arizona      Apache County     Write-ins   WRI           11  False
# 32145  Arizona     Cochise County  Donald Trump   REP        35557   True
# 32146  Arizona     Cochise County     Joe Biden   DEM        23732  False
# 32147  Arizona     Cochise County  Jo Jorgensen   LIB         1153  False
# 32148  Arizona     Cochise County     Write-ins   WRI           31  False
# 32149  Arizona    Coconino County     Joe Biden   DEM        44698   True
# 32150  Arizona    Coconino County  Donald Trump   REP        27052  False
# 32151  Arizona    Coconino County  Jo Jorgensen   LIB         1522  False
# 32152  Arizona    Coconino County     Write-ins   WRI           74  False
# 32153  Arizona        Gila County  Donald Trump   REP        18377   True
# 32154  Arizona        Gila County     Joe Biden   DEM         8943  False
# 32155  Arizona        Gila County  Jo Jorgensen   LIB          342  False
# 32156  Arizona        Gila County     Write-ins   WRI           16  False
# 32157  Arizona      Graham County  Donald Trump   REP        10749   True
# 32158  Arizona      Graham County     Joe Biden   DEM         4034  False
# 32159  Arizona      Graham County  Jo Jorgensen   LIB          212  False
# 32160  Arizona      Graham County     Write-ins   WRI            1  False
# 32161  Arizona    Greenlee County  Donald Trump   REP         2433   True
# 32162  Arizona    Greenlee County     Joe Biden   DEM         1182  False
# 32163  Arizona    Greenlee County  Jo Jorgensen   LIB           70  False
# 32164  Arizona    Greenlee County     Write-ins   WRI            3  False
# 32165  Arizona      La Paz County  Donald Trump   REP         5129   True
# 32166  Arizona      La Paz County     Joe Biden   DEM         2236  False
# 32167  Arizona      La Paz County  Jo Jorgensen   LIB           93  False
# 32168  Arizona      La Paz County     Write-ins   WRI            2  False
# 32169  Arizona    Maricopa County     Joe Biden   DEM      1040774   True
# 32170  Arizona    Maricopa County  Donald Trump   REP       995665  False
# 32171  Arizona    Maricopa County  Jo Jorgensen   LIB        31705  False
# 32172  Arizona    Maricopa County     Write-ins   WRI         1331  False
# 32173  Arizona      Mohave County  Donald Trump   REP        78535   True
# 32174  Arizona      Mohave County     Joe Biden   DEM        24831  False
# 32175  Arizona      Mohave County  Jo Jorgensen   LIB         1302  False
# 32176  Arizona      Mohave County     Write-ins   WRI           37  False

# %% [markdown]
# <h2><center> Summary </center></h2>
#
# ---

# %%
###

# %% [markdown]
# <h2><center> Future Steps </center></h2>
